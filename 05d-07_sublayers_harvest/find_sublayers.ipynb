# %%
import csv
from arcgis.gis import GIS
from urllib.request import urlopen
import json
from pyproj import Proj, transform
import time

# %%
item_dict = {}
with open('05d-07.csv') as f:
    reader = csv.reader(f)
    fieldnames = next(reader)
    for row in reader:
        ID = row[49]
        link = row[37]
        item_dict[ID] = link

del item_dict['05d-07']

# %%
# transform coordinates from projected coordinates to geographic coordinates
def convert_coords(extent):
    # spatial reference
    wkid = extent['spatialReference']['latestWkid']
    inProj = Proj(init='epsg:{}'.format(wkid))
    outProj = Proj(init='epsg:4326')   # WGS84
    
    x1 = extent['xmin']
    y1 = extent['ymin']
    x2 = extent['xmax']
    y2 = extent['ymax']
    
    xmin, ymin = transform(inProj, outProj, x1, y1)
    xmax, ymax = transform(inProj, outProj, x2, y2)
    
    return '{},{},{},{}'.format(round(xmin,4),round(ymin,4),round(xmax,4),round(ymax,4))

# %%
def harvest_metadata(json,content):
    layerID = json['id']
    title= ''
    alternativeTitle = json['name']
    description = json['description']
    language = 'eng'
    creator = 'U-Spatial'
    provider = 'University of Minnesota'
    resourceClass = '??? Web services'
    resourceType = ''
    isoTopCat = ''
    keyword = ''
    try:
        lastEditDate = json['editingInfo']['lastEditDate']
        dateIssued = time.strftime('%Y-%m-%d',time.localtime(lastEditDate/1000))
    except:
        dateIssued = ''
    temporalCoverage = ''
    dateRange = ''
    
    extent = json['extent']
    bbox = convert_coords(extent)
    spatialCoverage = ''
    
    memberOf = '??? 05d-07|b0153110-e455-4ced-9114-9b13250a7093'
    isPartOf = '??? '

    information = item_url+f'&sublayer={layerID}'  
    print(information)
    downloadURL = ''
    mapServer = ''
    featureServer = ''
    imageServer = ''
    if 'MapServer' in information:
        mapServer = f'{content.url}/{layerID}'
    elif 'FeatureServer' in information:
        featureServer = f'{content.url}/{layerID}'
    elif 'ImageServer' in information:
        imageServer = f'{content.url}/{layerID}'
    
    
    ID = f'??? {item_id}_{layerID}'   # ???
    identifier = information
    
    code = '05d-07'
    rights = ''
    accessRights = 'Public'
    accrualMethod = 'ArcGIS Python API'
    
    dateAccessioned = time.strftime("%Y-%m-%d")
    status = 'Active'
    suppressed = 'FALSE'
    child = '???'
    
    
    metadata = [title, alternativeTitle, description, language, creator, provider, resourceClass, resourceType,
               isoTopCat, keyword, dateIssued, temporalCoverage, dateRange, spatialCoverage, bbox, memberOf,
               isPartOf, information, downloadURL, mapServer, featureServer, imageServer, ID, identifier,
               code, rights, accessRights, accrualMethod, dateAccessioned, status, suppressed, child]
    
    return metadata

# %%
def find_sublayers(item_id,item_url):
    print(f'\n Finding sublayers for {item_id}')
    content = gis.content.get(item_id)
    feature_server_url = content.url + '?f=pjson'
    res = urlopen(feature_server_url)
    data_json = json.loads(res.read())
    layer_ids = [layer['id'] for layer in data_json['layers']]
    
    # visit layers one by one
    if len(layer_ids) > 1:
        for layerID in layer_ids:
            print(f'>>> Layer {layerID}:')
            layer_url = f'{content.url}/{layerID}?f=pjson'
            res_layer = urlopen(layer_url)
            layer_json = json.loads(res_layer.read())
            ALL_METADATA.append(harvest_metadata(layer_json,content))

# %%
ALL_METADATA = []
gis = GIS()
for k,v in item_dict.items():
    item_id = k
    item_url = v
    find_sublayers(item_id, item_url)
# Out:
#  Finding sublayers for f98867f6b4d84986905d89725b502ffe
#
#  Finding sublayers for 6a02959b55624c12b29da7b5cbb6b964
# >>> Layer 0:
# https://umn.maps.arcgis.com/home/item.html?id
# >>> Layer 0:
# https://umn.maps.arcgis.com/home/item.html?id=85e35d64d67f425c94ebca45dad6568a&sublayer=0
# >>> Layer 1:
# https://umn.maps.arcgis.com/home/item.html?id=85e35d64d67f425c94ebca45dad6568a&sublayer=1
# >>> Layer 2:
# https://umn.maps.arcgis.com/home/item.html?id=85e35d64d67f425c94ebca45dad6568a&sublayer=2
# >>> Layer 3:
# https://umn.maps.arcgis.com/home/item.html?id=85e35d64d67f425c94ebca45dad6568a&sublayer=3
# >>> Layer 4:
# https://umn.maps.arcgis.com/home/item.html?id=85e35d64d67f425c94ebca45dad6568a&sublayer=4
# >>> Layer 5:
# https://umn.maps.arcgis.com/home/item.html?id=85e35d64d67f425c94ebca45dad6568a&sublayer=5
# >>> Layer 6:
# https://umn.maps.arcgis.com/home/item.html?id=85e35d64d67f425c94ebca45dad6568a&sublayer=6
# >>> Layer 7:
# https://umn.maps.arcgis.com/home/item.html?id=85e35d64d67f425c94ebca45dad6568a&sublayer=7
#
#  Finding sublayers for 91663ad7f1444494900f7e1cf063bfe5
#
#  Finding sublayers for f3aef5e023a04785ba164ef217e4d685
#
#  Finding sublayers for c6c1d75dd78d4615ba501ea137b4a2f9
#
#  Finding sublayers for 426b954b5be74d599b6ce85f2ad10642
# >>> Layer 0:
# https://umn.maps.arcgis.com/home/item.html?id=426b954b5be74d599b6ce85f2ad10642&sublayer=0
# >>> Layer 1:
# https://umn.maps.arcgis.com/home/item.html?id=426b954b5be74d599b6ce85f2ad10642&sublayer=1
# >>> Layer 2:
# https://umn.maps.arcgis.com/home/item.html?id=426b954b5be74d599b6ce85f2ad10642&sublayer=2
# >>> Layer 3:
# https://umn.maps.arcgis.com/home/item.html?id=426b954b5be74d599b6ce85f2ad10642&sublayer=3
# >>> Layer 4:
# https://umn.maps.arcgis.com/home/item.html?id=426b954b5be74d599b6ce85f2ad10642&sublayer=4
# >>> Layer 5:
# https://umn.maps.arcgis.com/home/item.html?id=426b954b5be74d599b6ce85f2ad10642&sublayer=5
# >>> Layer 6:
# https://umn.maps.arcgis.com/home/item.html?id=426b954b5be74d599b6ce85f2ad10642&sublayer=6
#
#  Finding sublayers for 5d4a0f170e8e4858b8142ffc2057feb6
# >>> Layer 0:
# https://umn.maps.arcgis.com/home/item.html?id=5d4a0f170e8e4858b8142ffc2057feb6&sublayer=0
# >>> Layer 1:
# https://umn.maps.arcgis.com/home/item.html?id=5d4a0f170e8e4858b8142ffc2057feb6&sublayer=1
# >>> Layer 2:
# https://umn.maps.arcgis.com/home/item.html?id=5d4a0f170e8e4858b8142ffc2057feb6&sublayer=2
# >>> Layer 3:
# https://umn.maps.arcgis.com/home/item.html?id=5d4a0f170e8e4858b8142ffc2057feb6&sublayer=3
# >>> Layer 4:
# https://umn.maps.arcgis.com/home/item.html?id=5d4a0f170e8e4858b8142ffc2057feb6&sublayer=4
# >>> Layer 5:
# https://umn.maps.arcgis.com/home/item.html?id=5d4a0f170e8e4858b8142ffc2057feb6&sublayer=5
# >>> Layer 6:
# https://umn.maps.arcgis.com/home/item.html?id=5d4a0f170e8e4858b8142ffc2057feb6&sublayer=6
#
#  Finding sublayers for 1bb885a34b44491eb06c5681dd009d11
#
#  Finding sublayers for fbfa22fd77064334a5c0c452e9dd6084
# >>> Layer 0:
# https://umn.maps.arcgis.com/home/item.html?id=fbfa22fd77064334a5c0c452e9dd6084&sublayer=0
# >>> Layer 1:
# https://umn.maps.arcgis.com/home/item.html?id=fbfa22fd77064334a5c0c452e9dd6084&sublayer=1
#
#  Finding sublayers for c8ded0441a5b461baea3781dea67991c
# >>> Layer 0:
# https://umn.maps.arcgis.com/home/item.html?id=c8ded0441a5b461baea3781dea67991c&sublayer=0
# >>> Layer 1:
# https://umn.maps.arcgis.com/home/item.html?id=c8ded0441a5b461baea3781dea67991c&sublayer=1
#
#  Finding sublayers for 413dc260d00347b5a34cc3e3c9bed2c1
#
#  Finding sublayers for 067b224a0aa34f21b5fed74b69c78d3a
# >>> Layer 0:
# https://umn.maps.arcgis.com/home/item.html?id=067b224a0aa34f21b5fed74b69c78d3a&sublayer=0
# >>> Layer 1:
# https://umn.maps.arcgis.com/home/item.html?id=067b224a0aa34f21b5fed74b69c78d3a&sublayer=1
# >>> Layer 2:
# https://umn.maps.arcgis.com/home/item.html?id=067b224a0aa34f21b5fed74b69c78d3a&sublayer=2
# >>> Layer 3:
# https://umn.maps.arcgis.com/home/item.html?id=067b224a0aa34f21b5fed74b69c78d3a&sublayer=3
# >>> Layer 4:
# https://umn.maps.arcgis.com/home/item.html?id=067b224a0aa34f21b5fed74b69c78d3a&sublayer=4
# >>> Layer 5:
# https://umn.maps.arcgis.com/home/item.html?id=067b224a0aa34f21b5fed74b69c78d3a&sublayer=5
# >>> Layer 6:
# https://umn.maps.arcgis.com/home/item.html?id=067b224a0aa34f21b5fed74b69c78d3a&sublayer=6
#
#  Finding sublayers for dabaa491954d4b5c8ec4180ec0c312b3
#
#  Finding sublayers for 90fd878d53c346f49d81cb09e51ffe46
#
#  Finding sublayers for f227d1f03b1c49a9b30c1f82127cb2f0
# >>> Layer 0:
# https://umn.maps.arcgis.com/home/item.html?id=f227d1f03b1c49a9b30c1f82127cb2f0&sublayer=0
# >>> Layer 1:
# https://umn.maps.arcgis.com/home/item.html?id=f227d1f03b1c49a9b30c1f82127cb2f0&sublayer=1
# >>> Layer 2:
# https://umn.maps.arcgis.com/home/item.html?id=f227d1f03b1c49a9b30c1f82127cb2f0&sublayer=2
# >>> Layer 3:
# https://umn.maps.arcgis.com/home/item.html?id=f227d1f03b1c49a9b30c1f82127cb2f0&sublayer=3
# >>> Layer 4:
# https://umn.maps.arcgis.com/home/item.html?id=f227d1f03b1c49a9b30c1f82127cb2f0&sublayer=4
# >>> Layer 5:
# https://umn.maps.arcgis.com/home/item.html?id=f227d1f03b1c49a9b30c1f82127cb2f0&sublayer=5
# >>> Layer 6:
# https://umn.maps.arcgis.com/home/item.html?id=f227d1f03b1c49a9b30c1f82127cb2f0&sublayer=6
#
#  Finding sublayers for 0f4ba85f393c4a4d877265e52fc9c260
#
#  Finding sublayers for 87b1e7d2ecc94a3fa8a0d5c8f63b0dfa
# >>> Layer 0:
# https://umn.maps.arcgis.com/home/item.html?id=87b1e7d2ecc94a3fa8a0d5c8f63b0dfa&sublayer=0
# >>> Layer 1:
# https://umn.maps.arcgis.com/home/item.html?id=87b1e7d2ecc94a3fa8a0d5c8f63b0dfa&sublayer=1
# >>> Layer 2:
# https://umn.maps.arcgis.com/home/item.html?id=87b1e7d2ecc94a3fa8a0d5c8f63b0dfa&sublayer=2
# >>> Layer 3:
# https://umn.maps.arcgis.com/home/item.html?id=87b1e7d2ecc94a3fa8a0d5c8f63b0dfa&sublayer=3
# >>> Layer 4:
# https://umn.maps.arcgis.com/home/item.html?id=87b1e7d2ecc94a3fa8a0d5c8f63b0dfa&sublayer=4
# >>> Layer 5:
# https://umn.maps.arcgis.com/home/item.html?id=87b1e7d2ecc94a3fa8a0d5c8f63b0dfa&sublayer=5
# >>> Layer 6:
# https://umn.maps.arcgis.com/home/item.html?id=87b1e7d2ecc94a3fa8a0d5c8f63b0dfa&sublayer=6
#
#  Finding sublayers for 4a24cede1d9540a7a247710058d9d976
# >>> Layer 0:
# https://umn.maps.arcgis.com/home/item.html?id=4a24cede1d9540a7a247710058d9d976&sublayer=0
# >>> Layer 1:
# https://umn.maps.arcgis.com/home/item.html?id=4a24cede1d9540a7a247710058d9d976&sublayer=1
# >>> Layer 2:
# https://umn.maps.arcgis.com/home/item.html?id=4a24cede1d9540a7a247710058d9d976&sublayer=2
# >>> Layer 3:
# https://umn.maps.arcgis.com/home/item.html?id=4a24cede1d9540a7a247710058d9d976&sublayer=3
# >>> Layer 4:
# https://umn.maps.arcgis.com/home/item.html?id=4a24cede1d9540a7a247710058d9d976&sublayer=4
# >>> Layer 5:
# https://umn.maps.arcgis.com/home/item.html?id=4a24cede1d9540a7a247710058d9d976&sublayer=5
# >>> Layer 6:
# https://umn.maps.arcgis.com/home/item.html?id=4a24cede1d9540a7a247710058d9d976&sublayer=6
#
#  Finding sublayers for 48de6b14c74649579dbce8aa934e71d5
#
#  Finding sublayers for 3aab3102508542488f8b5de22bdd6b49
# >>> Layer 0:
# https://umn.maps.arcgis.com/home/item.html?id=3aab3102508542488f8b5de22bdd6b49&sublayer=0
# >>> Layer 1:
# https://umn.maps.arcgis.com/home/item.html?id=3aab3102508542488f8b5de22bdd6b49&sublayer=1
# >>> Layer 2:
# https://umn.maps.arcgis.com/home/item.html?id=3aab3102508542488f8b5de22bdd6b49&sublayer=2
# >>> Layer 3:
# https://umn.maps.arcgis.com/home/item.html?id=3aab3102508542488f8b5de22bdd6b49&sublayer=3
# >>> Layer 4:
# https://umn.maps.arcgis.com/home/item.html?id=3aab3102508542488f8b5de22bdd6b49&sublayer=4
# >>> Layer 5:
# https://umn.maps.arcgis.com/home/item.html?id=3aab3102508542488f8b5de22bdd6b49&sublayer=5
# >>> Layer 6:
# https://umn.maps.arcgis.com/home/item.html?id=3aab3102508542488f8b5de22bdd6b49&sublayer=6
#
#  Finding sublayers for 327065852ada450a8851f7dae4700c45
#
#  Finding sublayers for c2a192f6e22e40229c78719fc2bafab7
#
#  Finding sublayers for 4c20fe3080a94ee58f295a2e6b03b191
# >>> Layer 0:
# https://umn.maps.arcgis.com/home/item.html?id=4c20fe3080a94ee58f295a2e6b03b191&sublayer=0
# >>> Layer 1:
# https://umn.maps.arcgis.com/home/item.html?id=4c20fe3080a94ee58f295a2e6b03b191&sublayer=1
# >>> Layer 2:
# https://umn.maps.arcgis.com/home/item.html?id=4c20fe3080a94ee58f295a2e6b03b191&sublayer=2
# >>> Layer 3:
# https://umn.maps.arcgis.com/home/item.html?id=4c20fe3080a94ee58f295a2e6b03b191&sublayer=3
# >>> Layer 4:
# https://umn.maps.arcgis.com/home/item.html?id=4c20fe3080a94ee58f295a2e6b03b191&sublayer=4
# >>> Layer 5:
# https://umn.maps.arcgis.com/home/item.html?id=4c20fe3080a94ee58f295a2e6b03b191&sublayer=5
# >>> Layer 6:
# https://umn.maps.arcgis.com/home/item.html?id=4c20fe3080a94ee58f295a2e6b03b191&sublayer=6

# %%
fieldnames = ['Title', 'Alternative Title', 'Description', 'Language', 'Creator', 'Provider', 'Resource Class',
             'Resource Type', 'ISO Topic Categories', 'Keyword', 'Date Issued', 'Temporal Coverage', 'Date Range',
             'Spatial Coverage', 'Bounding Box', 'Member Of', 'Is Part Of', 'Information', 'Download', 'MapServer',
             'FeatureServer', 'ImageServer', 'ID', 'Identifier', 'Code', 'Rights', 'Access Rights', 'Accrual Method',
             'Date Accessioned', 'Status', 'Suppressed', 'Child Record']

# %%
with open('05d-07_sublayers.csv','w') as fw:
    writer = csv.writer(fw)
    writer.writerow(fieldnames)
    writer.writerows(ALL_METADATA)
